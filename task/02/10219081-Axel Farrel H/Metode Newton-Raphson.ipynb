# %%
#10219081-Axel Farrel Hutagalung

#Import Library
import math
#Definisi fungsi yang digunakan
def f(x):
    y = math.pow(x, 2) - (10*x) + 5
    return y

x = [i for i in range(-1,3)]
y = [f(i) for i in x]

def df(x):
    dy = (2*x) - 10
    return dy

# %%
xroot = []
yroot = []

x0 = 1
y0 = f(x0)

xroot.append(x0)
yroot.append(y0)

i = 1
eps = 1E-6
dx = 10
print("iter root         f(root)")
while dx > eps and i < 20:
    x0 = xroot[i-1]
    if i == 1:
        print(f"{i-1:04d}", f"{x0:.6E}", f"{f(x0):+.6E}")
    
    x1 = x0 - f(x0) / df(x0)
    
    xroot.append(x1)
    dx = abs(f(x1))
    
    print(f"{i:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 1.000000E+00 -4.000000E+00
# 0001 5.000000E-01 +2.500000E-01
# 0002 5.277778E-01 +7.716049E-04
# 0003 5.278640E-01 +7.441891E-09

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = 0.5278640441683919
# f(root) = 7.441890659265482e-09

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
