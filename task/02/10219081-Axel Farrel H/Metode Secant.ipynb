# %%
#10219081-Axel Farrel Hutagalung

#Import Library
import math
#Definisi fungsi yang digunakan
def f(x):
    y = math.pow(x, 2) - (10*x) + 5
    return y

x = [i for i in range(-5,5)]
y = [f(i) for i in x]

# %%
xroot = []
yroot = []

x0 = 1
y0 = f(x0)
xroot.append(x0)
yroot.append(y0)

x1 = 2
y1 = f(x1)
xroot.append(x1)
yroot.append(y1)

i = 2
eps = 1E-6
dx = 10
print("iter root         f(root)")
while dx > eps and i < 20:
    x0 = xroot[i-2]
    x1 = xroot[i-1]
    if i == 2:
        print(f"{i-2:04d}", f"{x0:.6E}", f"{f(x0):+.6E}")
        print(f"{i-1:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
    
    x2 = x1 - (x1 - x0) * f(x1) / ( f(x1) - f(x0) )
    
    xroot.append(x2)
    dx = abs(f(x2))
    
    print(f"{i:04d}", f"{x2:.6E}", f"{f(x2):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 1.000000E+00 -4.000000E+00
# 0001 2.000000E+00 -1.100000E+01
# 0002 4.285714E-01 +8.979592E-01
# 0003 5.471698E-01 -1.723033E-01
# 0004 5.280765E-01 -1.899884E-03
# 0005 5.278636E-01 +4.109872E-06
# 0006 5.278640E-01 -9.760814E-11

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = 0.5278640450113335
# f(root) = -9.760814378978466e-11

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
